# %%
import pandas as pd

# %%
df = pd.read_csv("data/data_index_per_fly.csv")
df = df.sort_values(by="Time of death (hours into video)", ascending=True).reset_index(
    drop=True
)
df["Fly id"] = df["Fly id"].astype(str)
df = df[df["Time of death (hours into video)"] > 0]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# use textwrap from python standard lib to help manage how the description
# text shows up
import textwrap

# %%
pal = sns.cubehelix_palette(df.shape[0], rot=-0.25, light=0.7)
print(pal.as_hex())
pal
# Out:
# ['#90c1c6', '#8cbec4', '#89bcc2', '#85b8c0', '#81b4be', '#7eb1bc', '#7baeba', '#78abb8', '#75a8b6', '#72a5b4', '#6fa1b2', '#6c9eb0', '#699bae', '#6697ac', '#6494aa', '#6191a7', '#5f8da5', '#5c8aa3', '#5a87a0', '#57839e', '#547f9b', '#527b98', '#507895', '#4e7493', '#4c7190', '#496d8d', '#476a8a', '#456687', '#436384', '#415f81', '#3f5c7e', '#3d587b', '#3b5577', '#395174', '#374e70', '#354b6d', '#334769', '#314364', '#2f3f60', '#2d3c5c', '#2b3958', '#293554', '#273250', '#252f4c', '#232b48', '#212843', '#1f253f']
# [[0.5632111255041908, 0.758620966612444, 0.7764634182455044],
#  [0.5494727325198484, 0.7470371296502942, 0.7691113867149812],
#  [0.5360110114598494, 0.7353151710761439, 0.7617456320925446],
#  [0.5228240791906859, 0.7234585216245827, 0.7543528888888889],
#  [0.5056649152479077, 0.707446410086458, 0.7444312760489047],
#  [0.49310949326943354, 0.695289848654309, 0.7369248563168074],
#  [0.4808195869245908, 0.6830113355545422, 0.7293484096039434],
#  [0.46879153169207444, 0.6706150659452972, 0.7216894286485516],
#  [0.4570212641324548, 0.6581053988009254, 0.7139356154941481],
#  [0.4455043271405808, 0.645486851912866, 0.7060748939784055],
#  [0.4342358755169504, 0.6327640967652975, 0.6980954220237603],
#  [0.42321068185390365, 0.6199419532892704, 0.6899856037212239],
#  [0.41242314273228897, 0.607025384499088, 0.6817341011990039],
#  [0.401867285224068, 0.5940194910147879, 0.6733298462676838],
#  [0.39153677369612416, 0.5809295054746382, 0.6647620518338492],
#  [0.38142491691035696, 0.5677607868416349, 0.6560202230742037],
#  [0.3715246754149566, 0.5545188146080532, 0.6470941683623626],
#  [0.36182866922157064, 0.5412091829021671, 0.6379740099406777],
#  [0.35232918576289274, 0.5278375945013134, 0.6286501943296033],
#  [0.3430181881250315, 0.5144098547555366, 0.619113502467283],
#  [0.3308822435042712, 0.496429068907903, 0.6060514841411274],
#  [0.32197803370002503, 0.4828934155900176, 0.5959841809384581],
#  [0.3132332886106476, 0.4693216231902486, 0.5856758110089167],
#  [0.30463866738797124, 0.45571986933681846, 0.5751187147066701],
#  [0.296184553136225, 0.44209440049272875, 0.5643056160378122],
#  [0.28786106274270273, 0.42845152541484527, 0.5532296309326825],
#  [0.2796580569367464, 0.41479760855617764, 0.5418842752001886],
#  [0.27156515057006514, 0.4011390634159816, 0.5302634721583539],
#  [0.2635717231112678, 0.38748234584234226, 0.5183615599355138],
#  [0.255666929347349, 0.37383394729193353, 0.5061732984367908],
#  [0.24783971028473523, 0.360200388051674, 0.49369387597068404],
#  [0.24007880424236577, 0.346588210427029, 0.48091891553082633],
#  [0.23237275812916042, 0.3330039719017312, 0.4678444807281714],
#  [0.22470993889810248, 0.3194542382737123, 0.4544670813690941],
#  [0.21707854516905067, 0.30594557677205786, 0.44078367867510504],
#  [0.2094666190122802, 0.292484549159813, 0.4267916901401091],
#  [0.20186205788464665, 0.27907770482747657, 0.41248899402135375],
#  [0.19171293514897592, 0.2612974804509568, 0.3929326133474375],
#  [0.18407777206007492, 0.2480424123637627, 0.3778993000025838],
#  [0.17640874387082348, 0.23486318078014537, 0.36255158444291735],
#  [0.1686932626621358, 0.22176620165767308, 0.34688938437109507],
#  [0.16091866179550793, 0.20875784178986662, 0.33091309587918094],
#  [0.1530722086213124, 0.1958444119535062, 0.3146235955451487],
#  [0.14514111727743262, 0.18303216008223688, 0.29802224214194734],
#  [0.13711256156942087, 0.1703272644713075, 0.28111087795723994],
#  [0.12897368792330136, 0.1577358270182646, 0.26389182972216774],
#  [0.12071162840208301, 0.14526386650440642, 0.2463679091477368]]

# %%
# plt.style.use("seaborn-whitegrid")  # set style because it looks nice
# plt.style.use("seaborn-white")  # set style because it looks nice
plt.style.use("default")  # set style because it looks nice

fig, ax = plt.subplots(1, 1, figsize=(3.75, 3.75), dpi=600)

# color palette to choose from
darkblue = "#1f253f"
lightblue = "#58849f"
redish = "#d73027"

DOT_SIZE = 50

# create the various dots
# avg dot
ax.scatter(
    x=df["Time of death (hours into video)"],
    y=df["Fly id"].astype(str),
    s=DOT_SIZE,
    alpha=1,
    label=None,
    color=pal,
    edgecolors="white",
)


x_min, x_max = ax.get_xlim()
y_min, y_max = ax.get_ylim()

# ax.plot([df["Time of death (hours into video)"].mean(),df["Time of death (hours into video)"].mean()], [y_min, y_max], linestyle="-", color="white", linewidth=3,alpha=0.4)
ax.plot(
    [
        df["Time of death (hours into video)"].mean(),
        df["Time of death (hours into video)"].mean(),
    ],
    [y_min, y_max],
    linestyle="--",
    color=redish,
    alpha=0.4,
)

ax.text(
    x=df["Time of death (hours into video)"].mean() - 1,
    y=(y_min) + 0.5,
    s="Mean lifespan",
    horizontalalignment="right",
    verticalalignment="bottom",
    fontsize=8,
    color=redish,
    rotation="vertical",
    # backgroundcolor="white",
    alpha=0.4,
)
ax.tick_params(color="darkgray", labelcolor="darkgray")
for spine in ax.spines.values():
    spine.set_edgecolor("darkgray")

# remove the y ticks
ax.set_yticks([])

ax.grid(False)
ax.spines["top"].set_visible(False)
# ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.spines["left"].set_visible(False)

ax.set_xticks([0, 24, 48, 72, 96, 120, 144, 168, 192])
ax.set_xlabel("Hours tracked (time of death) ", fontsize=8, color="dimgrey")

l = ax.legend(
    frameon=False,
    bbox_to_anchor=(0.6, 1.05),
    ncol=2,
    fontsize="x-large",
    labelcolor="dimgrey",
)


for text in l.get_texts():
    text.set_color("dimgrey")
ax.hlines(
    y=df["Fly id"],
    xmin=0,
    xmax=df["Time of death (hours into video)"],
    color="grey",
    alpha=0.4,
    lw=1,
    zorder=0,
)

plt.margins(x=0, y=0)
plt.xlim(0, 200)
plt.savefig("figures/lifespans.svg", dpi=600, bbox_inches="tight")
plt.show()
# Out:
# /Genomics/argo/users/swwolf/.conda/envs/sleap_dev/lib/python3.7/site-packages/ipykernel_launcher.py:50: MatplotlibDeprecationWarning: Support for passing numbers through unit converters is deprecated since 3.5 and support will be removed two minor releases later; use Axis.convert_units instead.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df["Time of death (hours into video)"].mean()
# Out:
# 118.80851063829788
